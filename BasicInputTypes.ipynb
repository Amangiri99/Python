# %% [markdown]
# #***Basic Input types***

# %%
print("HELLOWORLD")
# Out:
# HELLOWORLD

# %%
print("HELLO"+"WORLD")
# Out:
# HELLOWORLD

# %%
print(55/34)
# Out:
# 1.6176470588235294

# %%
print(2+1)
# Out:
# 3

# %%
type(5)
# Out:
# int

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
print(True and False)
# Out:
# False
