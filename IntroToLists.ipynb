# %% [markdown]
# ###***LISTS***

# %%
intro="My name,is,Aman Giri,comma"

# %%
a_list=intro.split(",")

# %%
print(a_list)
# Out:
# ['My name', 'is', 'Aman Giri', 'comma']

# %%
print(type(a_list))
# Out:
# <class 'list'>

# %%
print(a_list[0])
# Out:
# My name

# %%
print(a_list[2])
# Out:
# Aman Giri

# %%
print(a_list[-1])
# Out:
# comma

# %%
print(a_list[-2])
# Out:
# Aman Giri

# %%
print(type(a_list[1]))
# Out:
# <class 'str'>

# %%
print(a_list[2].upper())
a_list[2]=a_list[2].upper()
# Out:
# AMAN GIRI

# %%
print(a_list)
# Out:
# ['My name', 'is', 'AMAN GIRI', 'comma']

# %%
print(a_list[1:4])
# Out:
# ['is', 'AMAN GIRI', 'comma']

# %%
print(a_list[0:4:2])
# Out:
# ['My name', 'AMAN GIRI']

# %%
create_list=["Aman","Giri",16,"Jis","University"]

# %%
print(type(create_list))
print(type(create_list[2]))
# Out:
# <class 'list'>
# <class 'int'>

# %%
#Iterating through the list
for num in create_list:
    print(num)
# Out:
# Aman
# Giri
# 16
# Jis
# University

# %%
length=len(create_list)
print(length)
# Out:
# 5

# %%
i=0
while i<length:
    print(create_list[i])
    i+=1
# Out:
# Aman
# Giri
# 16
# Jis
# University

# %%
#Creating a new list
bmi_record=["AMAN GIRI",75,1.73,False]

# %%
for item in range(len(bmi_record)):
    print(item,bmi_record[item],type(bmi_record[item]))
# Out:
# 0 AMAN GIRI <class 'str'>
# 1 75 <class 'int'>
# 2 1.73 <class 'float'>
# 3 False <class 'bool'>

# %%
bmi_record[0]="KRISHNA KUMAR"

# %%
for item in range(len(bmi_record)):
    print(item,bmi_record[item],type(bmi_record[item]))
# Out:
# 0 KRISHNA KUMAR <class 'str'>
# 1 75 <class 'int'>
# 2 1.73 <class 'float'>
# 3 False <class 'bool'>

# %%
bmi_record.append("krishnakumar@gmail.com")

# %%
for item in range(len(bmi_record)):
    print(item,bmi_record[item])
# Out:
# 0 KRISHNA KUMAR
# 1 75
# 2 1.73
# 3 False
# 4 krishnakumar@gmail.com

# %%
bmi_dataset=[
             ["Krishna",75,1.93,False],
             ["Bheem",120,1.76,True]
]

# %%
print(type(bmi_dataset))
print(bmi_dataset[0],type(bmi_dataset[0]))
print(bmi_dataset[1],type(bmi_dataset[1]))
# Out:
# <class 'list'>
# ['Krishna', 75, 1.93, False] <class 'list'>
# ['Bheem', 120, 1.76, True] <class 'list'>

# %%
print(bmi_dataset[0][2])
# Out:
# 1.93

# %%
print(bmi_dataset[1][0],type(bmi_dataset[1][0]))
# Out:
# Bheem <class 'str'>

# %%
bmi_dataset[1][0]="AMAN"

# %%
bmi_dataset
# Out:
# [['Krishna', 75, 1.93, False], ['AMAN', 120, 1.76, True]]

# %%
bmi_dataset[1].append("ansugiri14@gmail.com")

# %%
bmi_dataset
# Out:
# [['Krishna', 75, 1.93, False],
#  ['AMAN', 120, 1.76, True, 'ansugiri14@gmail.com']]
