# %% [markdown]
# #***String Processing***

# %%
topic="Foundations of Data Science"

# %%
print(topic)
# Out:
# Foundations of Data Science

# %%
print(topic[0])
print(topic[1])
print(topic[10])
print(topic[-1])
print(topic[-3])
#Printing the value at certain index
# Out:
# F
# o
# s
# e
# n

# %%
print(topic[0:11]) #Slicing
# Out:
# Foundations

# %%
print(topic.lower()) #to convert a string to lowercase
# Out:
# foundations of data science

# %%
print(topic.upper())
# Out:
# FOUNDATIONS OF DATA SCIENCE

# %%
topic=topic.upper() #to convert a string to uppercase

# %%
print(topic)
# Out:
# FOUNDATIONS OF DATA SCIENCE

# %%
print(topic.islower()) #to check is a string is in lower case
# Out:
# False

# %%
print(topic.isupper())#to check is a string is in upperr case
# Out:
# True

# %%
print(topic.find("DATA")) #user defined function to find a string
# Out:
# 15

# %%
print(topic[15:19])
# Out:
# DATA

# %%
print(topic.replace("SCIENCE","ENGINEERING"))
# Out:
# FOUNDATIONS OF DATA ENGINEERING

# %%
2 ** 3
# Out:
# 8

# %%
print(55//34 ,55/34)
# Out:
# 1 1.6176470588235294

# %%
55%34
# Out:
# 21
