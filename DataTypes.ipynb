# %% [markdown]
# #***Data Types***

# %%
r_no=1729
print(r_no)
# Out:
# 1729

# %%
golden_ratio=55/34
print(golden_ratio,type(golden_ratio))
# Out:
# 1.6176470588235294 <class 'float'>

# %%
is_good=True
print(type(is_good))
# Out:
# <class 'bool'>

# %%
my_name=input("What is your name ")
# Out:
# What is your name Aman Giri

# %%
print(my_name , type(my_name))
# Out:
# Aman Giri <class 'str'>

# %%
print(my_name+ " is studying at " + another_school)
# Out:
# Aman Giri is studying at Jis University

# %%
hours_per_day=input("How many hours do you study per day")
# Out:
# How many hours do you study per day2

# %%
hours_per_day_int=int(hours_per_day) #Type Casting
print(hours_per_day_int , type(hours_per_day_int))
# Out:
# 2 <class 'int'>

# %%
hours_per_week=hours_per_day_int *7
print(hours_per_week)
# Out:
# 14

# %%
print("So "+my_name+ " you study for " +str(hours_per_week)+ " hours per week")
# Out:
# So Aman Giri you study for 14 hours per week
