# %% [markdown]
# #***Variable and Inputs***

# %%
school="Jis University"

# %%
print(school)
# Out:
# Jis University

# %%
print(type(school)) #Printing type of school
# Out:
# <class 'str'>

# %%
print(id(school))
# Out:
# 139769210530544

# %%
another_school=school

# %%
print(another_school)
# Out:
# Jis University

# %%
print(id(another_school))
# Out:
# 139769210530544

# %%
print("I am studying at "+another_school)
# Out:
# I am studying at Jis University
